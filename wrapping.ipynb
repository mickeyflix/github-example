# %%
import pandas as pd
url=("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M")
df=pd.read_html(url)

# %%
df[0].head()
# Out:
#   Postcode           Borough     Neighbourhood
# 0      M1A      Not assigned      Not assigned
# 1      M2A      Not assigned      Not assigned
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront

# %%
group=df[0].groupby(['Postcode','Neighbourhood','Borough'])

# %%
group.count()
# Out:
# Empty DataFrame
# Columns: []
# Index: [(M1A, Not assigned, Not assigned), (M1B, Malvern, Scarborough), (M1B, Rouge, Scarborough), (M1C, Highland Creek, Scarborough), (M1C, Port Union, Scarborough), (M1C, Rouge Hill, Scarborough), (M1E, Guildwood, Scarborough), (M1E, Morningside, Scarborough), (M1E, West Hill, Scarborough), (M1G, Woburn, Scarborough), (M1H, Cedarbrae, Scarborough), (M1J, Scarborough Village, Scarborough), (M1K, East Birchmount Park, Scarborough), (M1K, Ionview, Scarborough), (M1K, Kennedy Park, Scarborough), (M1L, Clairlea, Scarborough), (M1L, Golden Mile, Scarborough), (M1L, Oakridge, Scarborough), (M1M, Cliffcrest, Scarborough), (M1M, Cliffside, Scarborough), (M1M, Scarborough Village West, Scarborough), (M1N, Birch Cliff, Scarborough), (M1N, Cliffside West, Scarborough), (M1P, Dorset Park, Scarborough), (M1P, Scarborough Town Centre, Scarborough), (M1P, Wexford Heights, Scarborough), (M1R, Maryvale, Scarborough), (M1R, Wexford, Scarborough), (M1S, Agincourt, Scarborough), (M1T, Clarks Corners, Scarborough), (M1T, Sullivan, Scarborough), (M1T, Tam O'Shanter, Scarborough), (M1V, Agincourt North, Scarborough), (M1V, L'Amoreaux East, Scarborough), (M1V, Milliken, Scarborough), (M1V, Steeles East, Scarborough), (M1W, L'Amoreaux West, Scarborough), (M1X, Upper Rouge, Scarborough), (M1Y, Not assigned, Not assigned), (M1Z, Not assigned, Not assigned), (M2A, Not assigned, Not assigned), (M2B, Not assigned, Not assigned), (M2C, Not assigned, Not assigned), (M2E, Not assigned, Not assigned), (M2G, Not assigned, Not assigned), (M2H, Hillcrest Village, North York), (M2J, Fairview, North York), (M2J, Henry Farm, North York), (M2J, Oriole, North York), (M2K, Bayview Village, North York), (M2L, Silver Hills, North York), (M2L, York Mills, North York), (M2M, Newtonbrook, North York), (M2M, Willowdale, North York), (M2N, Willowdale South, North York), (M2P, York Mills West, North York), (M2R, Willowdale West, North York), (M2S, Not assigned, Not assigned), (M2T, Not assigned, Not assigned), (M2V, Not assigned, Not assigned), (M2W, Not assigned, Not assigned), (M2X, Not assigned, Not assigned), (M2Y, Not assigned, Not assigned), (M2Z, Not assigned, Not assigned), (M3A, Parkwoods, North York), (M3B, Don Mills North, North York), (M3C, Don Mills South, North York), (M3C, Flemingdon Park, North York), (M3E, Not assigned, Not assigned), (M3G, Not assigned, Not assigned), (M3H, Bathurst Manor, North York), (M3H, Downsview North, North York), (M3H, Wilson Heights, North York), (M3J, Northwood Park, North York), (M3J, York University, North York), (M3K, CFB Toronto, North York), (M3K, Downsview East, North York), (M3L, Downsview West, North York), (M3M, Downsview Central, North York), (M3N, Downsview Northwest, North York), (M3P, Not assigned, Not assigned), (M3R, Not assigned, Not assigned), (M3S, Not assigned, Not assigned), (M3T, Not assigned, Not assigned), (M3V, Not assigned, Not assigned), (M3W, Not assigned, Not assigned), (M3X, Not assigned, Not assigned), (M3Y, Not assigned, Not assigned), (M3Z, Not assigned, Not assigned), (M4A, Victoria Village, North York), (M4B, Parkview Hill, East York), (M4B, Woodbine Gardens, East York), (M4C, Woodbine Heights, East York), (M4E, The Beaches, East Toronto), (M4G, Leaside, East York), (M4H, Thorncliffe Park, East York), (M4J, East Toronto, East York), (M4K, Riverdale, East Toronto), (M4K, The Danforth West, East Toronto), (M4L, India Bazaar, East Toronto), ...]
#
# [288 rows x 0 columns]

# %%
table=df.groupby(['Postcode','Borough'],as_index=False, sort=False).agg(','.join)
table.head()
# Out:
#   Postcode           Borough             Neighbourhood
# 0      M1A      Not assigned              Not assigned
# 1      M2A      Not assigned              Not assigned
# 2      M3A        North York                 Parkwoods
# 3      M4A        North York          Victoria Village
# 4      M5A  Downtown Toronto  Harbourfront,Regent Park

# %%
df.shape
# Out:
# (180, 3)
